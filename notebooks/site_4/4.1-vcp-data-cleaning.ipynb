# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ## Table of Contents
# * [Fixing weather timestamp zone](#fix_timestamp)
# * [Splitting the data into training and test sets](#splitting)
# * [Missing values](#missing_values)
# * [Further cleaning](#further)

# %%
# Libraries

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

import os
import pandas as pd
import numpy as np
import datetime as dt
import gc
import missingno as msno
import pandas_profiling
import statsmodels as sm
from statsmodels.tsa.seasonal import seasonal_decompose
import random

from src.functions import data_import as dimp
from src.functions import data_exploration as dexp
from src.functions import data_transformation as dtr

#visualization
import matplotlib.pyplot as plt
import seaborn as sns
import plotly as pty

import plotly.graph_objs as go
from plotly.subplots import make_subplots
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import cufflinks as cf
cf.set_config_file(offline=True)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# Load train set
train_s4 = dimp.import_data('../../data/interim/site_4/train_s4_2.csv') 
train_s4['timestamp'] = pd.to_datetime(train_s4['timestamp'])
train_s4['year_built'] = pd.array(train_s4['year_built'], dtype=pd.Int16Dtype())
train_s4['floor_count'] = pd.array(train_s4['floor_count'], dtype=pd.Int16Dtype())
del train_s4['Unnamed: 0']
# Out:
# Memory usage of dataframe is 75.04 MB
# Memory usage after optimization is: 19.71 MB
# Decreased by 73.7%

# %% [markdown]
# ### Fixing weather timestamp zone
# <a id="fix_timestamp" />

# %%
# Convert weather timestamps in GMT to local time (GMT-8) (8 hours between maximum and minimum dayla temperature)
# We need to import raw data again and re-do the join
weather = dimp.import_data('../../data/raw/train/weather_train.csv')
train = dimp.import_data('../../data/raw/train/train.csv')
building_meta = dimp.import_data('../../data/raw/train/building_metadata.csv')
# Out:
# Memory usage of dataframe is 9.60 MB
# Memory usage after optimization is: 2.65 MB
# Decreased by 72.4%
# Memory usage of dataframe is 616.95 MB
# Memory usage after optimization is: 173.90 MB
# Decreased by 71.8%
# Memory usage of dataframe is 0.07 MB
# Memory usage after optimization is: 0.02 MB
# Decreased by 73.8%

# %%
# Timestamps to datetime
train['timestamp'] = pd.to_datetime(train['timestamp']).astype('datetime64[ns]')
weather['timestamp'] = pd.to_datetime(weather['timestamp'])

# %%
# Add -8 hours to weather timestamps
weather['timestamp'] += pd.DateOffset(hours=-8)

# %%
# Data join
df = pd.merge(
    pd.merge(building_meta, train, how='left', on='building_id'),
    weather,
    how='left',
    on=['site_id','timestamp']
)

df['year_built'] = pd.array(df['year_built'], dtype=pd.Int16Dtype())
df['floor_count'] = pd.array(df['floor_count'], dtype=pd.Int16Dtype())

# Rearranging columns
cols = [
    'site_id',
    'building_id', 
    'year_built', 
    'primary_use', 
    'floor_count', 
    'square_feet',
    'meter',  
    'timestamp',
    'air_temperature', 
    'cloud_coverage',
    'dew_temperature',
    'precip_depth_1_hr',
    'sea_level_pressure',
    'wind_direction',
    'wind_speed',
    'meter_reading'
]

df = df[cols]

# %%
# Filter by site_id 4
df_s4 = dimp.get_data_by_site(df, 4)

# %%
# Let's check the result by visualizating the data
df_s4[df_s4.building_id == 565].set_index('timestamp')[
    [
        'air_temperature',
        'meter_reading'
    ]
].iplot(kind='scatter', filename='cufflinks/cf-simple-line')
# Out:
# <div>
#
#
#             <div id="eea944c7-0ab3-4feb-9764-e0d448252093" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("eea944c7-0ab3-4feb-9764-e0d448252093")) {
#                     Plotly.newPlot(
#                         'eea944c7-0ab3-4feb-9764-e0d448252093',
#                         [{"line": {"color": "rgba(255, 153, 51, 1.0)", "dash": "solid", "shape": "linear", "width": 1.3}, "mode": "lines", "name": "air_temperature", "text": "", "type": "scatter", "x": ["2016-01-01 00:00:00", "2016-01-01 01:00:00", "2016-01-01 02:00:00", "2016-01-01 03:00:00", "2016-01-01 04:00:00", "2016-01-01 05:00:00", "2016-01-01 06:00:00", "2016-01-01 07:00:00", "2016-01-01 08:00:00", "2016-01-01 09:00:00", "2016-01-01 10:00:00", "2016-01-01 11:00:00", "2016-01-01 12:00:00", "2016-01-01 13:00:00", "2016-01-01 14:00:00", "2016-01-01 15:00:00", "2016-01-01 16:00:00", "2016-01-01 17:00:00", "2016-01-01 18:00:00", "2016-01-01 19:00:00", "2016-01-01 20:00:00", "2016-01-01 21:00:00", "2016-01-01 22:00:00", "2016-01-01 23:00:00", "2016-01-02 00:00:00", "2016-01-02 01:00:00", "2016-01-02 02:00:00", "2016-01-02 03:00:00", "2016-01-02 04:00:00", "2016-01-02 05:00:00", "2016-01-02 06:00:00", "2016-01-02 07:00:00", "2016-01-02 08:00:00", "2016-01-02 09:00:00", "2016-01-02 10:00:00", "2016-01-02 11:00:00", "2016-01-02 12:00:00", "2016-01-02 13:00:00", "2016-01-02 14:00:00", "2016-01-02 15:00:00", "2016-01-02 16:00:00", "2016-01-02 17:00:00", "2016-01-02 18:00:00", "2016-01-02 19:00:00", "2016-01-02 20:00:00", "2016-01-02 21:00:00", "2016-01-02 22:00:00", "2016-01-02 23:00:00", "2016-01-03 00:00:00", "2016-01-03 01:00:00", "2016-01-03 02:00:00", "2016-01-03 03:00:00", "2016-01-03 04:00:00", "2016-01-03 05:00:00", "2016-01-03 06:00:00", "2016-01-03 07:00:00", "2016-01-03 08:00:00", "2016-01-03 09:00:00", "2016-01-03 10:00:00", "2016-01-03 11:00:00", "2016-01-03 12:00:00", "2016-01-03 13:00:00", "2016-01-03 14:00:00", "2016-01-03 15:00:00", "2016-01-03 16:00:00", "2016-01-03 17:00:00", "2016-01-03 18:00:00", "2016-01-03 19:00:00", "2016-01-03 20:00:00", "2016-01-03 21:00:00", "2016-01-03 22:00:00", "2016-01-03 23:00:00", "2016-01-04 00:00:00", "2016-01-04 01:00:00", "2016-01-04 02:00:00", "2016-01-04 03:00:00", "2016-01-04 04:00:00", "2016-01-04 05:00:00", "2016-01-04 06:00:00", "2016-01-04 07:00:00", "2016-01-04 08:00:00", "2016-01-04 09:00:00", "2016-01-04 10:00:00", "2016-01-04 11:00:00", "2016-01-04 12:00:00", "2016-01-04 13:00:00", "2016-01-04 14:00:00", "2016-01-04 15:00:00", "2016-01-04 16:00:00", "2016-01-04 17:00:00", "2016-01-04 18:00:00", "2016-01-04 19:00:00", "2016-01-04 20:00:00", "2016-01-04 21:00:00", "2016-01-04 22:00:00", "2016-01-04 23:00:00", "2016-01-05 00:00:00", "2016-01-05 01:00:00", "2016-01-05 02:00:00", "2016-01-05 03:00:00", "2016-01-05 04:00:00", "2016-01-05 05:00:00", "2016-01-05 06:00:00", "2016-01-05 07:00:00", "2016-01-05 08:00:00", "2016-01-05 09:00:00", "2016-01-05 10:00:00", "2016-01-05 11:00:00", "2016-01-05 12:00:00", "2016-01-05 13:00:00", "2016-01-05 14:00:00", "2016-01-05 15:00:00", "2016-01-05 16:00:00", "2016-01-05 17:00:00", "2016-01-05 18:00:00", "2016-01-05 19:00:00", "2016-01-05 20:00:00", "2016-01-05 21:00:00", "2016-01-05 22:00:00", "2016-01-05 23:00:00", "2016-01-06 00:00:00", "2016-01-06 01:00:00", "2016-01-06 02:00:00", "2016-01-06 03:00:00", "2016-01-06 04:00:00", "2016-01-06 05:00:00", "2016-01-06 06:00:00", "2016-01-06 07:00:00", "2016-01-06 08:00:00", "2016-01-06 09:00:00", "2016-01-06 10:00:00", "2016-01-06 11:00:00", "2016-01-06 12:00:00", "2016-01-06 13:00:00", "2016-01-06 14:00:00", "2016-01-06 15:00:00", "2016-01-06 16:00:00", "2016-01-06 17:00:00", "2016-01-06 18:00:00", "2016-01-06 19:00:00", "2016-01-06 20:00:00", "2016-01-06 21:00:00", "2016-01-06 22:00:00", "2016-01-06 23:00:00", "2016-01-07 00:00:00", "2016-01-07 01:00:00", "2016-01-07 02:00:00", "2016-01-07 03:00:00", "2016-01-07 04:00:00", "2016-01-07 05:00:00", "2016-01-07 06:00:00", "2016-01-07 07:00:00", "2016-01-07 08:00:00", "2016-01-07 09:00:00", "2016-01-07 10:00:00", "2016-01-07 11:00:00", "2016-01-07 12:00:00", "2016-01-07 13:00:00", "2016-01-07 14:00:00", "2016-01-07 15:00:00", "2016-01-07 16:00:00", "2016-01-07 17:00:00", "2016-01-07 18:00:00", "2016-01-07 19:00:00", "2016-01-07 20:00:00", "2 ...

# %% [markdown]
# ### Splitting the data into training and test sets
# <a id="splitting" />

# %% [markdown]
# We're using the two last months of each building observations for testing the models. The rest of rows will conform the training data set.

# %%
# select the last two months of each building
date_time_str = '2016-10-31 23:00:00'
date_time_cut = dt.datetime.strptime(date_time_str, '%Y-%m-%d %H:%M:%S')

# create test and training sets
test_s4 = df_s4[df_s4['timestamp'] > date_time_cut]
train_s4 = df_s4[df_s4['timestamp'] <= date_time_cut]

# %%
len(test_s4) + len(train_s4)
# Out:
# 746746

# %%
test_s4.head()
# Out:
#          building_id  year_built primary_use  floor_count  square_feet  meter  \
# 6537747          565        1954   Education            2        15326      0
# 6537748          565        1954   Education            2        15326      0
# 6537749          565        1954   Education            2        15326      0
# 6537750          565        1954   Education            2        15326      0
# 6537751          565        1954   Education            2        15326      0
#
#                   timestamp  air_temperature  cloud_coverage  dew_temperature  \
# 6537747 2016-11-01 00:00:00        16.703125             NaN        12.796875
# 6537748 2016-11-01 01:00:00        16.093750             NaN        12.796875
# 6537749 2016-11-01 02:00:00        15.000000             NaN        13.296875
# 6537750 2016-11-01 03:00:00        15.601562             NaN        12.203125
# 6537751 2016-11-01 04:00:00        15.601562             NaN        12.203125
#
#          precip_depth_1_hr  sea_level_pressure  wind_direction  wind_speed  \
# 6537747                NaN              1015.5           190.0    4.601562
# 6537748                NaN              1015.5           160.0    6.199219
# 6537749                NaN              1016.0             0.0    0.000000
# 6537750                NaN              1015.5           230.0    3.099609
# 6537751                NaN              1016.0           230.0    3.599609
#
#          meter_reading
# 6537747           8.25
# 6537748           8.50
# 6537749           8.00
# 6537750           8.25
# 6537751           8.25

# %%
train_s4.tail()
# Out:
#          building_id  year_built primary_use  floor_count  square_feet  meter  \
# 7275705          655        1964   Education           11       222434      0
# 7275706          655        1964   Education           11       222434      0
# 7275707          655        1964   Education           11       222434      0
# 7275708          655        1964   Education           11       222434      0
# 7275709          655        1964   Education           11       222434      0
#
#                   timestamp  air_temperature  cloud_coverage  dew_temperature  \
# 7275705 2016-10-31 19:00:00        16.703125             NaN        11.703125
# 7275706 2016-10-31 20:00:00        16.093750             NaN        12.203125
# 7275707 2016-10-31 21:00:00        16.703125             NaN        13.296875
# 7275708 2016-10-31 22:00:00        16.703125             NaN        13.296875
# 7275709 2016-10-31 23:00:00        16.703125             NaN        12.796875
#
#          precip_depth_1_hr  sea_level_pressure  wind_direction  wind_speed  \
# 7275705                NaN              1014.5           170.0    7.699219
# 7275706                NaN              1015.0           180.0    6.199219
# 7275707                NaN              1015.0           220.0    5.699219
# 7275708                NaN              1015.5           220.0    5.699219
# 7275709                NaN              1015.0           200.0    4.601562
#
#          meter_reading
# 7275705     124.888000
# 7275706     122.206001
# 7275707     122.196999
# 7275708     120.597000
# 7275709     108.535004

# %%
# export training and test sets
train_s4.to_csv('../../data/interim/site_4/train_s4_2.csv')
test_s4.to_csv('../../data/interim/site_4/test_s4_2.csv')

# %% [markdown]
# ### Missing values
# <a id="missing_values"/>

# %%
# Çhecking missing values percentage
dexp.get_missing_percentage(
    train_s4.set_index(['building_id'])
)
# Out:
# year_built             1.24
# primary_use            0.00
# floor_count            0.00
# square_feet            0.00
# meter                  0.00
# air_temperature        0.00
# cloud_coverage        48.00
# dew_temperature        0.00
# precip_depth_1_hr     17.11
# sea_level_pressure     0.00
# wind_direction         0.00
# wind_speed             0.00
# meter_reading          0.00
# dtype: float64

# %% [markdown]
# #### Interpolation for some weather attributes
#
# Missing values in features in `dew_temperature`, `wind_direction` and `sea_level_pressure` will be filled by linear interpolation, concretly, by the method `time` of `interpolate()` pandas function.

# %%
train_s4.set_index('timestamp', inplace=True)

# %%
# Input air_temperature, dew_temperature and wind_direction missing values by interpolation
train_s4['dew_temperature'].interpolate(method='time', inplace=True)
train_s4['wind_direction'].interpolate(method='time', inplace=True)
train_s4['sea_level_pressure'].interpolate(method='time', inplace=True)

# %% [markdown]
# #### KNN for `year_built`

# %% [markdown]
# Some building metadata features may depend on the building age (`year_built`). We can add a new building metada feature, `building_age`, to classify the buildings depending on the year they were built. We'll create three categories:
# * old: before 1940
# * middle: between 1940 and 1980
# * new: after 1980 ('new' seems to not sound good for 40 years old bildings, but here it's only a label).
#
# This new feature will be used to input missing values in `year_built` by implementing the *KNN classification algorithm*: for every building with missing year built, KNN will classify it in one of the three age categories, which will allow to input the year built looking at the nearest neighbors year built value.

# %%
# Craete a copy of the training set and add the feature `building_age`.
train_cpy = train_s4.copy()
train_cpy = dtr.add_building_age_feature(train_cpy)

# %%
train_cpy.head()
# Out:
#    building_id  year_built primary_use  floor_count  square_feet  meter  \
# 0          565        1954   Education            2        15326      0
# 1          565        1954   Education            2        15326      0
# 2          565        1954   Education            2        15326      0
# 3          565        1954   Education            2        15326      0
# 4          565        1954   Education            2        15326      0
#
#             timestamp  air_temperature  cloud_coverage  dew_temperature  \
# 0 2016-01-01 00:00:00         4.398438             0.0        -2.199219
# 1 2016-01-01 01:00:00         4.398438             0.0        -4.398438
# 2 2016-01-01 02:00:00         4.398438             0.0        -6.699219
# 3 2016-01-01 03:00:00         4.398438             0.0        -7.800781
# 4 2016-01-01 04:00:00         5.000000             0.0        -9.398438
#
#    precip_depth_1_hr  sea_level_pressure  wind_direction  wind_speed  \
# 0                0.0              1021.0             0.0    0.000000
# 1                0.0              1020.5            20.0    2.099609
# 2                0.0              1021.0            20.0    2.099609
# 3                0.0              1020.5            30.0    2.599609
# 4                0.0              1020.5             0.0    0.000000
#
#    meter_reading building_age
# 0           7.25       middle
# 1           8.50       middle
# 2           7.25       middle
# 3           7.50       middle
# 4           8.00       middle

# %% [markdown]
# ### Further cleaning
# <a id="further"/>

# %%
train_s4.isna().count()
# Out:
# building_id           614709
# year_built            614709
# primary_use           614709
# floor_count           614709
# square_feet           614709
# meter                 614709
# timestamp             614709
# air_temperature       614709
# cloud_coverage        614709
# dew_temperature       614709
# precip_depth_1_hr     614709
# sea_level_pressure    614709
# wind_direction        614709
# wind_speed            614709
# meter_reading         614709
# dtype: int64

# %%
# Delete column `meter` as there's only one type of meter (electricity)
del train_s4['meter']

# %%
 train_s4.set_index('timestamp')[['air_temperature','dew_temperature']]
# Out:
#                      air_temperature  dew_temperature
# timestamp
# 2016-01-01 00:00:00         4.398438        -2.199219
# 2016-01-01 01:00:00         4.398438        -4.398438
# 2016-01-01 02:00:00         4.398438        -6.699219
# 2016-01-01 03:00:00         4.398438        -7.800781
# 2016-01-01 04:00:00         5.000000        -9.398438
# ...                              ...              ...
# 2016-10-31 19:00:00        16.703125        11.703125
# 2016-10-31 20:00:00        16.093750        12.203125
# 2016-10-31 21:00:00        16.703125        13.296875
# 2016-10-31 22:00:00        16.703125        13.296875
# 2016-10-31 23:00:00        16.703125        12.796875
#
# [614709 rows x 2 columns]
